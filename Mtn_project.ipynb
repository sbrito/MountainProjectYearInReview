# %%
import pandas as pd

# url = 'https://www.mountainproject.com/user/201330145/stephanie-brito/tick-export'  # Replace with your CSV URL

# %%
user_input = input("Please enter your mountain project user URL: ")
# Out:
# Please enter your mountain project user URL: https://www.mountainproject.com/user/201330145/stephanie-brito/tick-export

# %%
data = pd.read_csv(url)

# %%
data.head()
# Out:
#          Date             Route   Rating  \
# 0  2023-11-24  Turkish Standard    5.11b
# 1  2023-11-24           Firtina      5.9
# 2  2023-11-24       Piano Hands  5.10a/b
# 3  2023-11-23     3 Oda 1 Salon    5.10b
# 4  2023-11-23   Silvie's Secret      5.9
#
#                                                Notes  \
# 0  First attempt on 11a outside! Made it up and i...
# 1                                                NaN
# 2              Missed the side pulls. Amazing climb
# 3                                                NaN
# 4            A lil run out. It was so hot and greasy
#
#                                                  URL  Pitches  \
# 0  https://www.mountainproject.com/route/10846092...        1
# 1  https://www.mountainproject.com/route/11654844...        1
# 2  https://www.mountainproject.com/route/10846085...        1
# 3  https://www.mountainproject.com/route/11699449...        1
# 4  https://www.mountainproject.com/route/10716836...        1
#
# ...
